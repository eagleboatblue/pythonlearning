# %% [markdown]
# # Number
# * int
# * float
# * complex

# %%
a = 5
a, type(a)
# Out:
# (5, int)

# %%
b = 4.5
b, type(b)
# Out:
# (4.5, float)

# %%
c = 3 - 5j
c, type(c)
# Out:
# ((3-5j), complex)

# %% [markdown]
# # String
# a string could be inside of 2 apostrophe ‘’
# or 3 apostrophy '''It's so nice.'''
# or 3 double quate """Hello the world"""

# %%
s = "Hello"
s, type(s)
# Out:
# ('Hello', str)

# %%
s = """John said:"I'm John." """
s, type(s)
# Out:
# ('John said:"I\'m John." ', str)

# %%
s1 = b'Hello the world!'
type(s1), s1
# Out:
# (bytes, b'Hello the world!')

# %% [markdown]
# String is iterable

# %%
for i in s:
  print(i, end=', ')
# Out:
# J, o, h, n,  , s, a, i, d, :, ", I, ', m,  , J, o, h, n, ., ",  ,

# %% [markdown]
# String can be sliced

# %%
s[5:10], s[11], s[11:]
# Out:
# ('said:', 'I', 'I\'m John." ')

# %% [markdown]
# Strig is immutable。

# %%
s[5] = 'A'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0323a8084aba> in <module>
# ----> 1 s[5] = 'A'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# there are some functions available for a string variable.

# %%
s.upper()
# Out:
# 'JOHN SAID:"I\'M JOHN." '

# %%
s.isdecimal(), s.isdigit()
# Out:
# (False, False)

# %%
s.lower()
# Out:
# 'john said:"i\'m john." '

# %%
s.center(80)
# Out:
# '                             John said:"I\'m John."                              '

# %% [markdown]
# str() built in function can be used to convert number to string.

# %%
a, str(a)
# Out:
# (5, '5')

# %%
str([1,2,3,4])
# Out:
# '[1, 2, 3, 4]'

# %% [markdown]
# # Tuple

# %% [markdown]
# Create a tuple

# %%
t1 = (1,2,3,4,5,6,7)
print(t1) 
type(t1)
# Out:
# (1, 2, 3, 4, 5, 6, 7)
# tuple

# %% [markdown]
# Tuple is iterable

# %%
for i in t1:
    print(i, end=', ')
# Out:
# 1, 2, 3, 4, 5, 6, 7,

# %% [markdown]
# # List

# %% [markdown]
# create a list variable

# %%
j1= [1,2,3,4]
print(j1)
type(j1)
# Out:
# [1, 2, 3, 4]
# list

# %% [markdown]
# list is iterable

# %%
for i in j1:
  print(i, end=", ")
# Out:
# 1, 2, 3, 4,

# %% [markdown]
# list can be sliced

# %%
j1[1], j1[2:]
# Out:
# (2, [3, 4])

# %% [markdown]
# list is mutable

# %%
j1[0]='Hello'
j1
# Out:
# ['Hello', 2, 3, 4]

# %% [markdown]
# there are some function available for a list, len()

# %%
len(j1)
# Out:
# 4

# %%
list2 = [3]*5
list2
# Out:
# [3, 3, 3, 3, 3]

# %% [markdown]
# # Set
